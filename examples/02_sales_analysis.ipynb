# %% [markdown]
# # Sales Analysis with Luxin
#
# A realistic example analyzing sales data with drill-down capabilities.

# %%
import pandas as pd
import numpy as np
from luxin import TrackedDataFrame

# Set seed for reproducibility
np.random.seed(42)

# %% [markdown]
# ## Generate Sample Sales Data

# %%
# Generate 100 transactions
n_transactions = 100

categories = ['Electronics', 'Clothing', 'Food', 'Books', 'Home']
regions = ['North', 'South', 'East', 'West']

df = TrackedDataFrame({
    'transaction_id': range(1, n_transactions + 1),
    'category': np.random.choice(categories, n_transactions),
    'region': np.random.choice(regions, n_transactions),
    'amount': np.random.uniform(10, 500, n_transactions).round(2),
    'quantity': np.random.randint(1, 10, n_transactions)
})

print(f"Generated {len(df)} transactions")
df.head(10)
# Out:
# Generated 100 transactions
#    transaction_id  category region  amount  quantity
# 0               1     Books   West  271.70         2
# 1               2      Home   East  247.57         5
# 2               3      Food  North  349.29         1
# 3               4      Home   West  142.01         1
# 4               5      Home   West  129.62         5
# 5               6  Clothing  South   92.46         3
# 6               7      Food  North  117.19         4
# 7               8      Food   West  283.47         3
# 8               9      Food   East  207.88         1
# 9              10      Home   East   41.80         1

# %% [markdown]
# ## Analysis 1: Sales by Category

# %%
category_summary = df.groupby('category').agg({
    'amount': ['sum', 'mean', 'count'],
    'quantity': 'sum'
})

category_summary.columns = ['Total Sales', 'Avg Sale', 'Num Transactions', 'Total Quantity']
category_summary = category_summary.sort_values('Total Sales', ascending=False)

category_summary
# Out:
#              Total Sales    Avg Sale  Num Transactions  Total Quantity
# category
# Clothing         6809.48  324.260952                21             110
# Books            6746.58  259.483846                26             125
# Home             5564.34  292.860000                19              88
# Food             4324.30  270.268750                16              70
# Electronics      3851.20  213.955556                18              78

# %%
# Click on a category to see all transactions!
category_summary.show_drill_table()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <style>
#         /* Luxin Interactive Table Styles */
#
# .luxin-container {
#     display: flex;
#     gap: 20px;
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial, sans-serif;
#     position: relative;
#     width: 100%;
#     max-width: 100%;
#     min-height: 400px;
#     overflow: visible;
# }
#
# .main-table-container {
#     flex: 1;
#     min-width: 0;
#     transition: margin-right 0.3s ease, width 0.3s ease;
# }
#
# .luxin-container:has(.detail-panel.open) .main-table-container {
#     margin-right: 620px;
# }
#
# .main-table-container h3 {
#     margin-top: 0;
#     margin-bottom: 15px;
#     color: #333;
#     font-size: 18px;
# }
#
# .table-wrapper {
#     overflow-x: auto;
#     border: 1px solid #ddd;
#     border-radius: 4px;
# }
#
# .luxin-container table {
#     border-collapse: collapse;
#     width: 100%;
#     background: white;
# }
#
# .luxin-container thead {
#     background-color: #f8f9fa;
#     border-bottom: 2px solid #dee2e6;
# }
#
# .luxin-container th {
#     padding: 12px;
#     text-align: left;
#     font-weight: 600;
#     color: #495057;
#     border-bottom: 1px solid #dee2e6;
# }
#
# .luxin-container td {
#     padding: 10px 12px;
#     border-bottom: 1px solid #f0f0f0;
#     color: #333;
# }
#
# .luxin-container tbody tr {
#     cursor: pointer;
#     transition: background-color 0.15s ease;
# }
#
# .luxin-container tbody tr:hover {
#     background-color: #f8f9fa;
# }
#
# .luxin-container tbody tr.selected {
#     background-color: #e7f3ff;
# }
#
# .detail-panel {
#     position: absolute;
#     right: -600px;
#     top: 0;
#     width: 600px;
#     min-height: 100%;
#     max-height: 600px;
#     background: white;
#     border-left: 1px solid #ddd;
#     box-shadow: -2px 0 8px rgba(0,0,0,0.1);
#     transition: right 0.3s ease;
#     z-index: 1000;
#     overflow-y: auto;
# }
#
# .detail-panel.open {
#     right: 0;
# }
#
# .detail-panel-header {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     padding: 20px;
#     border-bottom: 1px solid #ddd;
#     position: sticky;
#     top: 0;
#     background: white;
#     z-index: 1;
# }
#
# .detail-panel-header h3 {
#     margin: 0;
#     color: #333;
#     font-size: 18px;
# }
#
# .close-button {
#     background: none;
#     border: none;
#     font-size: 28px;
#     color: #666;
#     cursor: pointer;
#     padding: 0;
#     width: 32px;
#     height: 32px;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     border-radius: 4px;
#     transition: background-color 0.15s ease;
# }
#
# .close-button:hover {
#     background-color: #f0f0f0;
#     color: #333;
# }
#
# .detail-content {
#     padding: 20px;
# }
#
# .detail-placeholder {
#     color: #999;
#     text-align: center;
#     padding: 40px 20px;
# }
#
# .detail-content table {
#     font-size: 14px;
# }
#
# .detail-content td,
# .detail-content th {
#     padding: 8px 10px;
# }
#
# /* Loading state */
# .detail-content.loading::after {
#     content: "Loading...";
#     display: block;
#     text-align: center;
#     color: #999;
#     padding: 40px 20px;
# }
#
# /* Responsive design */
# @media (max-width: 768px) {
#     .detail-panel {
#         width: 100%;
#         right: -100%;
#     }
# }
#
#
#     </style>
# </head>
# <body>
#     <div class="luxin-container" id="luxin-container-7sl8wz92">
#         <div class="main-table-container" id="main-table-7sl8wz92">
#             <h3>Aggregated Data</h3>
#             <div class="table-wrapper">
#                 <table class="dataframe luxin-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Total Sales</th>
#       <th>Avg Sale</th>
#       <th>Num Transactions</th>
#       <th>Total Quantity</th>
#     </tr>
#     <tr>
#       <th>category</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Clothing</th>
#       <td>6809.48</td>
#       <td>324.260952</td>
#       <td>21</td>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>Books</th>
#       <td>6746.58</td>
#       <td>259.483846</td>
#       <td>26</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>Home</th>
#       <td>5564.34</td>
#       <td>292.860000</td>
#       <td>19</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>Food</th>
#       <td>4324.30</td>
#       <td>270.268750</td>
#       <td>16</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>Electronics</th>
#       <td>3851.20</td>
#       <td>213.955556</td>
#       <td>18</td>
#       <td>78</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div id="detail-panel-7sl8wz92" class="detail-panel">
#             <div class="detail-panel-header">
#                 <h3>Detail Rows</h3>
#                 <button id="close-panel-7sl8wz92" class="close-button">&times;</button>
#             </div>
#             <div id="detail-content-7sl8wz92" class="detail-content">
#                 <p class="detail-placeholder">Click on a row to see details</p>
#             </div>
#         </div>
#     </div>
#
#     <script>
#         // Luxin Interactive Table JavaScript
#
# (function() {
#     // Store the source mapping and detail data
#     const sourceMapping = {
#   "Books": [
#     "0",
#     "10",
#     "14",
#     "16",
#     "19",
#     "22",
#     "28",
#     "29",
#     "31",
#     "32",
#     "40",
#     "42",
#     "49",
#     "50",
#     "51",
#     "52",
#     "56",
#     "58",
#     "61",
#     "65",
#     "68",
#     "69",
#     "77",
#     "78",
#     "79",
#     "88"
#   ],
#   "Clothing": [
#     "5",
#     "13",
#     "15",
#     "20",
#     "27",
#     "39",
#     "43",
#     "44",
#     "46",
#     "48",
#     "57",
#     "59",
#     "60",
#     "63",
#     "64",
#     "66",
#     "67",
#     "73",
#     "75",
#     "97",
#     "98"
#   ],
#   "Electronics": [
#     "18",
#     "23",
#     "24",
#     "33",
#     "38",
#     "41",
#     "45",
#     "55",
#     "70",
#     "76",
#     "81",
#     "84",
#     "85",
#     "86",
#     "87",
#     "91",
#     "94",
#     "99"
#   ],
#   "Food": [
#     "2",
#     "6",
#     "7",
#     "8",
#     "11",
#     "25",
#     "26",
#     "30",
#     "34",
#     "36",
#     "54",
#     "89",
#     "90",
#     "92",
#     "93",
#     "95"
#   ],
#   "Home": [
#     "1",
#     "3",
#     "4",
#     "9",
#     "12",
#     "17",
#     "21",
#     "35",
#     "37",
#     "47",
#     "53",
#     "62",
#     "71",
#     "72",
#     "74",
#     "80",
#     "82",
#     "83",
#     "96"
#   ]
# };
#     const detailData = {
#   "0": {
#     "transaction_id": 1,
#     "category": "Books",
#     "region": "West",
#     "amount": 271.7,
#     "quantity": 2
#   },
#   "1": {
#     "transaction_id": 2,
#     "category": "Home",
#     "region": "East",
#     "amount": 247.57,
#     "quantity": 5
#   },
#   "2": {
#     "transaction_id": 3,
#     "category": "Food",
#     "region": "North",
#     "amount": 349.29,
#     "quantity": 1
#   },
#   "3": {
#     "transaction_id": 4,
#     "category": "Home",
#     "region": "West",
#     "amount": 142.01,
#     "quantity": 1
#   },
#   "4": {
#     "transaction_id": 5,
#     "category": "Home",
#     "region": "West",
#     "amount": 129.62,
#     "quantity": 5
#   },
#   "5": {
#     "transaction_id": 6,
#     "category": "Clothing",
#     "region": "South",
#     "amount": 92.46,
#     "quantity": 3
#   },
#   "6": {
#     "transaction_id": 7,
#     "category": "Food",
#     "region": "North",
#     "amount": 117.19,
#     "quantity": 4
#   },
#   "7": {
#     "transaction_id": 8,
#     "category": "Food",
#     "region": "West",
#     "amount": 283.47,
#     "quantity": 3
#   },
#   "8": {
#     "transaction_id": 9,
#     "category": "Food",
#     "region": "East",
#     "amount": 207.88,
#     "quantity": 1
#   },
#   "9": {
#     "transaction_id": 10,
#     "category": "Home",
#     "region": "East",
#     "amount": 41.8,
#     "quantity": 1
#   },
#   "10": {
#     "transaction_id": 11,
#     "category": "Books",
#     "region": "South",
#     "amount": 134.42,
#     "quantity": 5
#   },
#   "11": {
#     "transaction_id": 12,
#     "category": "Food",
#     "region": "West",
#     "amount": 130.97,
#     "quantity": 6
#   },
#   "12": {
#     "transaction_id": 13,
#     "category": "Home",
#     "region": "North",
#     "amount": 351.19,
#     "quantity": 3
#   },
#   "13": {
#     "transaction_id": 14,
#     "category": "Clothing",
#     "region": "East",
#     "amount": 359.01,
#     "quantity": 9
#   },
#   "14": {
#     "transaction_id": 15,
#     "category": "Books",
#     "region": "West",
#     "amount": 82.56,
#     "quantity": 5
#   },
#   "15": {
#     "transa

# %% [markdown]
# ## Analysis 2: Sales by Region and Category

# %%
region_category = df.groupby(['region', 'category']).agg({
    'amount': 'sum',
    'quantity': 'sum',
    'transaction_id': 'count'
})

region_category.columns = ['Total Sales', 'Total Quantity', 'Num Transactions']

# Show top 10
region_category_top = region_category.sort_values('Total Sales', ascending=False).head(10)
region_category_top
# Out:
#                  Total Sales  Total Quantity  Num Transactions
# region category
# East   Books         2680.28              51                10
# South  Books         2229.64              32                 7
# West   Clothing      2183.49              39                 7
# East   Home          1991.43              28                 7
# West   Home          1939.61              36                 7
# East   Clothing      1932.57              30                 5
# North  Food          1831.03              35                 7
#        Clothing      1507.17              24                 4
# East   Food          1332.12              15                 4
# South  Clothing      1186.25              17                 5

# %%
# Click on any region-category combination
region_category_top.show_drill_table()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <style>
#         /* Luxin Interactive Table Styles */
#
# .luxin-container {
#     display: flex;
#     gap: 20px;
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial, sans-serif;
#     position: relative;
#     width: 100%;
#     max-width: 100%;
#     min-height: 400px;
#     overflow: visible;
# }
#
# .main-table-container {
#     flex: 1;
#     min-width: 0;
#     transition: margin-right 0.3s ease, width 0.3s ease;
# }
#
# .luxin-container:has(.detail-panel.open) .main-table-container {
#     margin-right: 620px;
# }
#
# .main-table-container h3 {
#     margin-top: 0;
#     margin-bottom: 15px;
#     color: #333;
#     font-size: 18px;
# }
#
# .table-wrapper {
#     overflow-x: auto;
#     border: 1px solid #ddd;
#     border-radius: 4px;
# }
#
# .luxin-container table {
#     border-collapse: collapse;
#     width: 100%;
#     background: white;
# }
#
# .luxin-container thead {
#     background-color: #f8f9fa;
#     border-bottom: 2px solid #dee2e6;
# }
#
# .luxin-container th {
#     padding: 12px;
#     text-align: left;
#     font-weight: 600;
#     color: #495057;
#     border-bottom: 1px solid #dee2e6;
# }
#
# .luxin-container td {
#     padding: 10px 12px;
#     border-bottom: 1px solid #f0f0f0;
#     color: #333;
# }
#
# .luxin-container tbody tr {
#     cursor: pointer;
#     transition: background-color 0.15s ease;
# }
#
# .luxin-container tbody tr:hover {
#     background-color: #f8f9fa;
# }
#
# .luxin-container tbody tr.selected {
#     background-color: #e7f3ff;
# }
#
# .detail-panel {
#     position: absolute;
#     right: -600px;
#     top: 0;
#     width: 600px;
#     min-height: 100%;
#     max-height: 600px;
#     background: white;
#     border-left: 1px solid #ddd;
#     box-shadow: -2px 0 8px rgba(0,0,0,0.1);
#     transition: right 0.3s ease;
#     z-index: 1000;
#     overflow-y: auto;
# }
#
# .detail-panel.open {
#     right: 0;
# }
#
# .detail-panel-header {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     padding: 20px;
#     border-bottom: 1px solid #ddd;
#     position: sticky;
#     top: 0;
#     background: white;
#     z-index: 1;
# }
#
# .detail-panel-header h3 {
#     margin: 0;
#     color: #333;
#     font-size: 18px;
# }
#
# .close-button {
#     background: none;
#     border: none;
#     font-size: 28px;
#     color: #666;
#     cursor: pointer;
#     padding: 0;
#     width: 32px;
#     height: 32px;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     border-radius: 4px;
#     transition: background-color 0.15s ease;
# }
#
# .close-button:hover {
#     background-color: #f0f0f0;
#     color: #333;
# }
#
# .detail-content {
#     padding: 20px;
# }
#
# .detail-placeholder {
#     color: #999;
#     text-align: center;
#     padding: 40px 20px;
# }
#
# .detail-content table {
#     font-size: 14px;
# }
#
# .detail-content td,
# .detail-content th {
#     padding: 8px 10px;
# }
#
# /* Loading state */
# .detail-content.loading::after {
#     content: "Loading...";
#     display: block;
#     text-align: center;
#     color: #999;
#     padding: 40px 20px;
# }
#
# /* Responsive design */
# @media (max-width: 768px) {
#     .detail-panel {
#         width: 100%;
#         right: -100%;
#     }
# }
#
#
#     </style>
# </head>
# <body>
#     <div class="luxin-container" id="luxin-container-wmovabf2">
#         <div class="main-table-container" id="main-table-wmovabf2">
#             <h3>Aggregated Data</h3>
#             <div class="table-wrapper">
#                 <table class="dataframe luxin-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Total Sales</th>
#       <th>Total Quantity</th>
#       <th>Num Transactions</th>
#     </tr>
#     <tr>
#       <th>region</th>
#       <th>category</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>East</th>
#       <th>Books</th>
#       <td>2680.28</td>
#       <td>51</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>South</th>
#       <th>Books</th>
#       <td>2229.64</td>
#       <td>32</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>West</th>
#       <th>Clothing</th>
#       <td>2183.49</td>
#       <td>39</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>East</th>
#       <th>Home</th>
#       <td>1991.43</td>
#       <td>28</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>West</th>
#       <th>Home</th>
#       <td>1939.61</td>
#       <td>36</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>East</th>
#       <th>Clothing</th>
#       <td>1932.57</td>
#       <td>30</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">North</th>
#       <th>Food</th>
#       <td>1831.03</td>
#       <td>35</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Clothing</th>
#       <td>1507.17</td>
#       <td>24</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>East</th>
#       <th>Food</th>
#       <td>1332.12</td>
#       <td>15</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>South</th>
#       <th>Clothing</th>
#       <td>1186.25</td>
#       <td>17</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div id="detail-panel-wmovabf2" class="detail-panel">
#             <div class="detail-panel-header">
#                 <h3>Detail Rows</h3>
#                 <button id="close-panel-wmovabf2" class="close-button">&times;</button>
#             </div>
#             <div id="detail-content-wmovabf2" class="detail-content">
#                 <p class="detail-placeholder">Click on a row to see details</p>
#             </div>
#         </div>
#     </div>
#
#     <script>
#         // Luxin Interactive Table JavaScript
#
# (function() {
#     // Store the source mapping and detail data
#     const sourceMapping = {
#   "East|Books": [
#     "22",
#     "28",
#     "29",
#     "31",
#     "32",
#     "40",
#     "51",
#     "52",
#     "61",
#     "79"
#   ],
#   "East|Clothing": [
#     "13",
#     "20",
#     "43",
#     "60",
#     "97"
#   ],
#   "East|Electronics": [
#     "18",
#     "24",
#     "41",
#     "55",
#     "85"
#   ],
#   "East|Food": [
#     "8",
#     "34",
#     "54",
#     "90"
#   ],
#   "East|Home": [
#     "1",
#     "9",
#     "17",
#     "35",
#     "62",
#     "82",
#     "96"
#   ],
#   "North|Books": [
#     "19",
#     "50",
#     "56",
#     "58",
#     "69",
#     "88"
#   ],
#   "North|Clothing": [
#     "39",
#     "44",
#     "46",
#     "67"
#   ],
#   "North|Electronics": [
#     "33",
#     "70",
#     "84",
#     "87",
#     "94"
#   ],
#   "North|Food": [
#     "2",
#     "6",
#     "25",
#     "26",
#     "89",
#     "92",
#     "95"
#   ],
#   "North|Home": [
#     "12",
#     "21",
#     "53"
#   ],
#   "South|Books": [
#     "10",
#     "16",
#     "49",
#     "65",
#     "68",
#     "77",
#     "78"
#   ],
#   "South|Clothing": [
#     "5",
#     "27",
#     "63",
#     "66",
#     "98"
#   ],
#   "South|Electronics": [
#     "23",
#     "81",
#     "86",
#     "91"
#   ],
#   "South|Food": [
#     "30",
#     "36"
#   ],
#   "South|Home": [
#     "37",
#     "71"
#   ],
#   "West|Books": [
#     "0",
#     "14",
#     "42"
#   ],
#   "West|Clothing": [
#     "15",
#     "48",
#     "57",
#     "59",
#     "64",
#     "73",
#     "75"
#   ],
#   "West|Electronics": [
#     "38",
#     "45",
#     "76",
#     "99"
#   ],
#   "West|Food": [
#     "7",
#     "11",
#     "93"
#   ],
#   "West|Home": [
#     "3",
#     "4",
#     "47",
#     "72",
#     "74",
#     "80",
#     "83"
#   ]
# };
#     const detailData = {
#   "0": {
#     "transaction_id": 1,
#     "category": "Books",
#     "region": "West",
#     "amount": 271.7,
#     "quantity": 2
#   },
#   "1": {
#     "transaction_id": 2,
#     "category": "Home",
#     "region": "East",
#     "amount": 247.57,
#     "quantity": 5
#   },
#   "2": {
#     "transaction_id": 3,
#     "category": "Food",
#     "region": "North",
#     "amount": 349.29,
#     "quantity": 1
#   },
#   "3": {
#     "transaction_id": 4,
#     "category": "Home",
#     "region": "West",
#     "amount": 142.01,
#     "quantity": 1
#   },
#   "4": {
#     "transaction_id": 5,
#     "category": "Home",
#     "region": "West",
#     "amount": 129.62,
#     "quantity": 5
#   },
#   "5": {
#     "transaction_id": 6,
#     "category": "Clothing",
#     "region": "South",
#     "amount": 92.46,
#     "quantity": 3
#   },
#   "6": {
#     "transaction_id": 7,
#     "category": "Food",
#     "region": "North",
#     "amount": 117.19,
#     "quantity": 4
#   },
#   "7": {
#     "transaction_id": 8,
#     "category": "Food",
#     "region": "West",
#     "amoun
