# %% [markdown]
# # Multi-Column GroupBy with Luxin
#
# Demonstrating complex grouping scenarios with multiple columns.

# %%
import pandas as pd
import numpy as np
from luxin import TrackedDataFrame

np.random.seed(100)

# %% [markdown]
# ## Example 1: Two-Column GroupBy

# %%
n = 50
df = TrackedDataFrame({
    'region': np.random.choice(['North', 'South', 'East', 'West'], n),
    'product': np.random.choice(['Product A', 'Product B', 'Product C'], n),
    'sales': np.random.uniform(100, 1000, n).round(2),
    'units': np.random.randint(1, 20, n)
})

print(f"Generated {len(df)} records")
df.head()
# Out:
# Generated 50 records
#   region    product   sales  units
# 0  North  Product A  554.89      2
# 1  North  Product C  438.63      9
# 2   West  Product B  633.52     19
# 3   West  Product B  666.95     19
# 4   West  Product C  228.34      8

# %%
# Group by region and product
regional_product = df.groupby(['region', 'product']).agg({
    'sales': ['sum', 'mean'],
    'units': 'sum'
})

regional_product.columns = ['Total Sales', 'Avg Sale', 'Total Units']
regional_product = regional_product.sort_values('Total Sales', ascending=False)

regional_product.head(10)
# Out:
#                   Total Sales    Avg Sale  Total Units
# region product
# West   Product C      4424.33  632.047143           65
# North  Product C      3399.17  566.528333           62
# East   Product C      3316.39  552.731667           66
# South  Product A      2932.08  586.416000           55
#        Product B      2782.40  556.480000           41
# West   Product B      2690.45  538.090000           90
#        Product A      2399.94  599.985000           30
# East   Product A      2390.93  796.976667           41
# North  Product B      1964.97  654.990000           43
#        Product A      1772.78  443.195000           44

# %%
# Click on any region-product combination
regional_product.head(10).show_drill_table()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <style>
#         /* Luxin Interactive Table Styles */
#
# .luxin-container {
#     display: flex;
#     gap: 20px;
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial, sans-serif;
#     position: relative;
#     width: 100%;
#     max-width: 100%;
#     min-height: 400px;
#     overflow: visible;
# }
#
# .main-table-container {
#     flex: 1;
#     min-width: 0;
#     transition: margin-right 0.3s ease, width 0.3s ease;
# }
#
# .luxin-container:has(.detail-panel.open) .main-table-container {
#     margin-right: 620px;
# }
#
# .main-table-container h3 {
#     margin-top: 0;
#     margin-bottom: 15px;
#     color: #333;
#     font-size: 18px;
# }
#
# .table-wrapper {
#     overflow-x: auto;
#     border: 1px solid #ddd;
#     border-radius: 4px;
# }
#
# .luxin-container table {
#     border-collapse: collapse;
#     width: 100%;
#     background: white;
# }
#
# .luxin-container thead {
#     background-color: #f8f9fa;
#     border-bottom: 2px solid #dee2e6;
# }
#
# .luxin-container th {
#     padding: 12px;
#     text-align: left;
#     font-weight: 600;
#     color: #495057;
#     border-bottom: 1px solid #dee2e6;
# }
#
# .luxin-container td {
#     padding: 10px 12px;
#     border-bottom: 1px solid #f0f0f0;
#     color: #333;
# }
#
# .luxin-container tbody tr {
#     cursor: pointer;
#     transition: background-color 0.15s ease;
# }
#
# .luxin-container tbody tr:hover {
#     background-color: #f8f9fa;
# }
#
# .luxin-container tbody tr.selected {
#     background-color: #e7f3ff;
# }
#
# .detail-panel {
#     position: absolute;
#     right: -600px;
#     top: 0;
#     width: 600px;
#     min-height: 100%;
#     max-height: 600px;
#     background: white;
#     border-left: 1px solid #ddd;
#     box-shadow: -2px 0 8px rgba(0,0,0,0.1);
#     transition: right 0.3s ease;
#     z-index: 1000;
#     overflow-y: auto;
# }
#
# .detail-panel.open {
#     right: 0;
# }
#
# .detail-panel-header {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     padding: 20px;
#     border-bottom: 1px solid #ddd;
#     position: sticky;
#     top: 0;
#     background: white;
#     z-index: 1;
# }
#
# .detail-panel-header h3 {
#     margin: 0;
#     color: #333;
#     font-size: 18px;
# }
#
# .close-button {
#     background: none;
#     border: none;
#     font-size: 28px;
#     color: #666;
#     cursor: pointer;
#     padding: 0;
#     width: 32px;
#     height: 32px;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     border-radius: 4px;
#     transition: background-color 0.15s ease;
# }
#
# .close-button:hover {
#     background-color: #f0f0f0;
#     color: #333;
# }
#
# .detail-content {
#     padding: 20px;
# }
#
# .detail-placeholder {
#     color: #999;
#     text-align: center;
#     padding: 40px 20px;
# }
#
# .detail-content table {
#     font-size: 14px;
# }
#
# .detail-content td,
# .detail-content th {
#     padding: 8px 10px;
# }
#
# /* Loading state */
# .detail-content.loading::after {
#     content: "Loading...";
#     display: block;
#     text-align: center;
#     color: #999;
#     padding: 40px 20px;
# }
#
# /* Responsive design */
# @media (max-width: 768px) {
#     .detail-panel {
#         width: 100%;
#         right: -100%;
#     }
# }
#
#
#     </style>
# </head>
# <body>
#     <div class="luxin-container" id="luxin-container-lzueqqto">
#         <div class="main-table-container" id="main-table-lzueqqto">
#             <h3>Aggregated Data</h3>
#             <div class="table-wrapper">
#                 <table class="dataframe luxin-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Total Sales</th>
#       <th>Avg Sale</th>
#       <th>Total Units</th>
#     </tr>
#     <tr>
#       <th>region</th>
#       <th>product</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>West</th>
#       <th>Product C</th>
#       <td>4424.33</td>
#       <td>632.047143</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>North</th>
#       <th>Product C</th>
#       <td>3399.17</td>
#       <td>566.528333</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>East</th>
#       <th>Product C</th>
#       <td>3316.39</td>
#       <td>552.731667</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">South</th>
#       <th>Product A</th>
#       <td>2932.08</td>
#       <td>586.416000</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>Product B</th>
#       <td>2782.40</td>
#       <td>556.480000</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">West</th>
#       <th>Product B</th>
#       <td>2690.45</td>
#       <td>538.090000</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>Product A</th>
#       <td>2399.94</td>
#       <td>599.985000</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>East</th>
#       <th>Product A</th>
#       <td>2390.93</td>
#       <td>796.976667</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">North</th>
#       <th>Product B</th>
#       <td>1964.97</td>
#       <td>654.990000</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>Product A</th>
#       <td>1772.78</td>
#       <td>443.195000</td>
#       <td>44</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div id="detail-panel-lzueqqto" class="detail-panel">
#             <div class="detail-panel-header">
#                 <h3>Detail Rows</h3>
#                 <button id="close-panel-lzueqqto" class="close-button">&times;</button>
#             </div>
#             <div id="detail-content-lzueqqto" class="detail-content">
#                 <p class="detail-placeholder">Click on a row to see details</p>
#             </div>
#         </div>
#     </div>
#
#     <script>
#         // Luxin Interactive Table JavaScript
#
# (function() {
#     // Store the source mapping and detail data
#     const sourceMapping = {
#   "East|Product A": [
#     "7",
#     "14",
#     "28"
#   ],
#   "East|Product B": [
#     "12",
#     "23"
#   ],
#   "East|Product C": [
#     "8",
#     "10",
#     "13",
#     "15",
#     "29",
#     "48"
#   ],
#   "North|Product A": [
#     "0",
#     "17",
#     "22",
#     "39"
#   ],
#   "North|Product B": [
#     "6",
#     "9",
#     "31"
#   ],
#   "North|Product C": [
#     "1",
#     "18",
#     "20",
#     "24",
#     "32",
#     "38"
#   ],
#   "South|Product A": [
#     "11",
#     "16",
#     "36",
#     "44",
#     "46"
#   ],
#   "South|Product B": [
#     "26",
#     "27",
#     "34",
#     "35",
#     "47"
#   ],
#   "West|Product A": [
#     "30",
#     "33",
#     "42",
#     "45"
#   ],
#   "West|Product B": [
#     "2",
#     "3",
#     "19",
#     "21",
#     "43"
#   ],
#   "West|Product C": [
#     "4",
#     "5",
#     "25",
#     "37",
#     "40",
#     "41",
#     "49"
#   ]
# };
#     const detailData = {
#   "0": {
#     "region": "North",
#     "product": "Product A",
#     "sales": 554.89,
#     "units": 2
#   },
#   "1": {
#     "region": "North",
#     "product": "Product C",
#     "sales": 438.63,
#     "units": 9
#   },
#   "2": {
#     "region": "West",
#     "product": "Product B",
#     "sales": 633.52,
#     "units": 19
#   },
#   "3": {
#     "region": "West",
#     "product": "Product B",
#     "sales": 666.95,
#     "units": 19
#   },
#   "4": {
#     "region": "West",
#     "product": "Product C",
#     "sales": 228.34,
#     "units": 8
#   },
#   "5": {
#     "region": "West",
#     "product": "Product C",
#     "sales": 940.46,
#     "units": 3
#   },
#   "6": {
#     "region": "North",
#     "product": "Product B",
#     "sales": 951.74,
#     "units": 18
#   },
#   "7": {
#     "region": "East",
#     "product": "Product A",
#     "sales": 642.07,
#     "units": 3
#   },
#   "8": {
#     "region": "East",
#     "product": "Product C",
#     "sales": 448.99,
#     "units": 18
#   },
#   "9": {
#     "region": "North",
#     "product": "Product B",
#     "sales": 426.87,
#     "units": 14
#   },
#   "10": {
#     "region": "East",
#     "product": "Product C",
#     "sales": 283.91,
#     "units": 1
#   },
#   "11": {
#     "region": "South",
#     "product": "Product A",
#     "sales": 349.09,
#     "units": 11
#   },
#   "12": {
#     "region": "East",
#     "product": "Product B",
#     "sales": 321.88,
#     "units": 4
#   },
#   "13": {
#     "region": "East",
#     "product": "Product C",
#     "sales": 256.25,
#     "units": 6
#   },
#   "14": {
#     "region": "East",
#     "product": "Product A",
#     "sales": 969.95,
#     "units": 19
#   },
#   "15": {
#     "region"

# %% [markdown]
# ## Example 2: Customer Segmentation

# %%
customers = TrackedDataFrame({
    'customer_id': range(1, 81),
    'age_group': np.random.choice(['18-25', '26-35', '36-45', '46+'], 80),
    'location': np.random.choice(['Urban', 'Suburban', 'Rural'], 80),
    'purchase_amount': np.random.uniform(50, 500, 80).round(2),
    'satisfaction': np.random.randint(1, 6, 80)
})

customers.head()
# Out:
#    customer_id age_group location  purchase_amount  satisfaction
# 0            1     26-35    Urban           322.30             5
# 1            2     26-35    Rural           301.65             3
# 2            3     26-35    Urban           437.18             2
# 3            4       46+    Urban           463.89             5
# 4            5     36-45    Urban           432.32             1

# %%
demo_analysis = customers.groupby(['age_group', 'location']).agg({
    'purchase_amount': ['sum', 'mean', 'count'],
    'satisfaction': 'mean'
})

demo_analysis.columns = ['Total $', 'Avg $', 'Count', 'Avg Satisfaction']
demo_analysis = demo_analysis.round(2)

demo_analysis
# Out:
#                     Total $   Avg $  Count  Avg Satisfaction
# age_group location
# 18-25     Rural     1170.48  292.62      4              4.00
#           Suburban  2218.18  316.88      7              2.14
#           Urban     2086.97  231.89      9              2.44
# 26-35     Rural     2480.48  275.61      9              2.78
#           Suburban  1489.04  212.72      7              3.29
#           Urban     2165.95  360.99      6              3.33
# 36-45     Rural      913.71  228.43      4              3.75
#           Suburban  1464.10  366.02      4              3.50
#           Urban     3216.71  321.67     10              3.10
# 46+       Rural     1603.98  320.80      5              3.40
#           Suburban  1571.93  157.19     10              3.40
#           Urban     1048.42  209.68      5              2.60

# %%
# See individual customers in each segment
demo_analysis.show_drill_table()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <style>
#         /* Luxin Interactive Table Styles */
#
# .luxin-container {
#     display: flex;
#     gap: 20px;
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial, sans-serif;
#     position: relative;
#     width: 100%;
#     max-width: 100%;
#     min-height: 400px;
#     overflow: visible;
# }
#
# .main-table-container {
#     flex: 1;
#     min-width: 0;
#     transition: margin-right 0.3s ease, width 0.3s ease;
# }
#
# .luxin-container:has(.detail-panel.open) .main-table-container {
#     margin-right: 620px;
# }
#
# .main-table-container h3 {
#     margin-top: 0;
#     margin-bottom: 15px;
#     color: #333;
#     font-size: 18px;
# }
#
# .table-wrapper {
#     overflow-x: auto;
#     border: 1px solid #ddd;
#     border-radius: 4px;
# }
#
# .luxin-container table {
#     border-collapse: collapse;
#     width: 100%;
#     background: white;
# }
#
# .luxin-container thead {
#     background-color: #f8f9fa;
#     border-bottom: 2px solid #dee2e6;
# }
#
# .luxin-container th {
#     padding: 12px;
#     text-align: left;
#     font-weight: 600;
#     color: #495057;
#     border-bottom: 1px solid #dee2e6;
# }
#
# .luxin-container td {
#     padding: 10px 12px;
#     border-bottom: 1px solid #f0f0f0;
#     color: #333;
# }
#
# .luxin-container tbody tr {
#     cursor: pointer;
#     transition: background-color 0.15s ease;
# }
#
# .luxin-container tbody tr:hover {
#     background-color: #f8f9fa;
# }
#
# .luxin-container tbody tr.selected {
#     background-color: #e7f3ff;
# }
#
# .detail-panel {
#     position: absolute;
#     right: -600px;
#     top: 0;
#     width: 600px;
#     min-height: 100%;
#     max-height: 600px;
#     background: white;
#     border-left: 1px solid #ddd;
#     box-shadow: -2px 0 8px rgba(0,0,0,0.1);
#     transition: right 0.3s ease;
#     z-index: 1000;
#     overflow-y: auto;
# }
#
# .detail-panel.open {
#     right: 0;
# }
#
# .detail-panel-header {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     padding: 20px;
#     border-bottom: 1px solid #ddd;
#     position: sticky;
#     top: 0;
#     background: white;
#     z-index: 1;
# }
#
# .detail-panel-header h3 {
#     margin: 0;
#     color: #333;
#     font-size: 18px;
# }
#
# .close-button {
#     background: none;
#     border: none;
#     font-size: 28px;
#     color: #666;
#     cursor: pointer;
#     padding: 0;
#     width: 32px;
#     height: 32px;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     border-radius: 4px;
#     transition: background-color 0.15s ease;
# }
#
# .close-button:hover {
#     background-color: #f0f0f0;
#     color: #333;
# }
#
# .detail-content {
#     padding: 20px;
# }
#
# .detail-placeholder {
#     color: #999;
#     text-align: center;
#     padding: 40px 20px;
# }
#
# .detail-content table {
#     font-size: 14px;
# }
#
# .detail-content td,
# .detail-content th {
#     padding: 8px 10px;
# }
#
# /* Loading state */
# .detail-content.loading::after {
#     content: "Loading...";
#     display: block;
#     text-align: center;
#     color: #999;
#     padding: 40px 20px;
# }
#
# /* Responsive design */
# @media (max-width: 768px) {
#     .detail-panel {
#         width: 100%;
#         right: -100%;
#     }
# }
#
#
#     </style>
# </head>
# <body>
#     <div class="luxin-container" id="luxin-container-ovqpfe2w">
#         <div class="main-table-container" id="main-table-ovqpfe2w">
#             <h3>Aggregated Data</h3>
#             <div class="table-wrapper">
#                 <table class="dataframe luxin-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Total $</th>
#       <th>Avg $</th>
#       <th>Count</th>
#       <th>Avg Satisfaction</th>
#     </tr>
#     <tr>
#       <th>age_group</th>
#       <th>location</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">18-25</th>
#       <th>Rural</th>
#       <td>1170.48</td>
#       <td>292.62</td>
#       <td>4</td>
#       <td>4.00</td>
#     </tr>
#     <tr>
#       <th>Suburban</th>
#       <td>2218.18</td>
#       <td>316.88</td>
#       <td>7</td>
#       <td>2.14</td>
#     </tr>
#     <tr>
#       <th>Urban</th>
#       <td>2086.97</td>
#       <td>231.89</td>
#       <td>9</td>
#       <td>2.44</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">26-35</th>
#       <th>Rural</th>
#       <td>2480.48</td>
#       <td>275.61</td>
#       <td>9</td>
#       <td>2.78</td>
#     </tr>
#     <tr>
#       <th>Suburban</th>
#       <td>1489.04</td>
#       <td>212.72</td>
#       <td>7</td>
#       <td>3.29</td>
#     </tr>
#     <tr>
#       <th>Urban</th>
#       <td>2165.95</td>
#       <td>360.99</td>
#       <td>6</td>
#       <td>3.33</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">36-45</th>
#       <th>Rural</th>
#       <td>913.71</td>
#       <td>228.43</td>
#       <td>4</td>
#       <td>3.75</td>
#     </tr>
#     <tr>
#       <th>Suburban</th>
#       <td>1464.10</td>
#       <td>366.02</td>
#       <td>4</td>
#       <td>3.50</td>
#     </tr>
#     <tr>
#       <th>Urban</th>
#       <td>3216.71</td>
#       <td>321.67</td>
#       <td>10</td>
#       <td>3.10</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">46+</th>
#       <th>Rural</th>
#       <td>1603.98</td>
#       <td>320.80</td>
#       <td>5</td>
#       <td>3.40</td>
#     </tr>
#     <tr>
#       <th>Suburban</th>
#       <td>1571.93</td>
#       <td>157.19</td>
#       <td>10</td>
#       <td>3.40</td>
#     </tr>
#     <tr>
#       <th>Urban</th>
#       <td>1048.42</td>
#       <td>209.68</td>
#       <td>5</td>
#       <td>2.60</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div id="detail-panel-ovqpfe2w" class="detail-panel">
#             <div class="detail-panel-header">
#                 <h3>Detail Rows</h3>
#                 <button id="close-panel-ovqpfe2w" class="close-button">&times;</button>
#             </div>
#             <div id="detail-content-ovqpfe2w" class="detail-content">
#                 <p class="detail-placeholder">Click on a row to see details</p>
#             </div>
#         </div>
#     </div>
#
#     <script>
#         // Luxin Interactive Table JavaScript
#
# (function() {
#     // Store the source mapping and detail data
#     const sourceMapping = {
#   "18-25|Rural": [
#     "37",
#     "45",
#     "59",
#     "72"
#   ],
#   "18-25|Suburban": [
#     "15",
#     "21",
#     "24",
#     "35",
#     "48",
#     "56",
#     "64"
#   ],
#   "18-25|Urban": [
#     "10",
#     "16",
#     "31",
#     "39",
#     "49",
#     "51",
#     "54",
#     "62",
#     "75"
#   ],
#   "26-35|Rural": [
#     "1",
#     "9",
#     "17",
#     "29",
#     "41",
#     "42",
#     "52",
#     "53",
#     "61"
#   ],
#   "26-35|Suburban": [
#     "14",
#     "28",
#     "34",
#     "40",
#     "58",
#     "68",
#     "69"
#   ],
#   "26-35|Urban": [
#     "0",
#     "2",
#     "8",
#     "11",
#     "19",
#     "47"
#   ],
#   "36-45|Rural": [
#     "33",
#     "43",
#     "44",
#     "74"
#   ],
#   "36-45|Suburban": [
#     "6",
#     "13",
#     "23",
#     "46"
#   ],
#   "36-45|Urban": [
#     "4",
#     "20",
#     "30",
#     "36",
#     "38",
#     "57",
#     "63",
#     "67",
#     "70",
#     "78"
#   ],
#   "46+|Rural": [
#     "18",
#     "27",
#     "32",
#     "66",
#     "73"
#   ],
#   "46+|Suburban": [
#     "5",
#     "7",
#     "25",
#     "50",
#     "60",
#     "65",
#     "71",
#     "76",
#     "77",
#     "79"
#   ],
#   "46+|Urban": [
#     "3",
#     "12",
#     "22",
#     "26",
#     "55"
#   ]
# };
#     const detailData = {
#   "0": {
#     "customer_id": 1,
#     "age_group": "26-35",
#     "location": "Urban",
#     "purchase_amount": 322.3,
#     "satisfaction": 5
#   },
#   "1": {
#     "customer_id": 2,
#     "age_group": "26-35",
#     "location": "Rural",
#     "purchase_amount": 301.65,
#     "satisfaction": 3
#   },
#   "2": {
#     "customer_id": 3,
#     "age_group": "26-35",
#     "location": "Urban",
#     "purchase_amount": 437.18,
#     "satisfaction": 2
#   },
#   "3": {
#     "customer_id": 4,
#     "age_group": "46+",
#     "location": "Urban",
#     "purchase_amount": 463.89,
#     "satisfaction": 5
#   },
#   "4": {
#     "customer_id": 5,
#     "age_group": "36-45",
#     "location": "Urban",
#     "purchase_amount": 432.32,
#     "satisfaction": 1
#   },
#   "5": {
#     "customer_id": 6,
#     "age_group": "46+",
#     "location": "Suburban",
#     "purchase_amount": 164.51,
#     "satisfaction": 5
#   },
#   "6": {
#     "customer_id": 7,
#     "age_
